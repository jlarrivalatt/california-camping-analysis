# %%
import pandas as pd
import numpy as np

# %%
camping_df = pd.read_csv('camping_res21.csv')

# %%
camping_df.head()
# Out:
#                  ParkName  ParkId                        FacilityName  \
# 0  Anza-Borrego Desert SP       2  Borrego Palm Canyon (sites 90-120)
# 1  Anza-Borrego Desert SP       2  Borrego Palm Canyon (sites 90-120)
# 2  Anza-Borrego Desert SP       2  Borrego Palm Canyon (sites 90-120)
# 3  Anza-Borrego Desert SP       2  Borrego Palm Canyon (sites 90-120)
# 4  Anza-Borrego Desert SP       2  Borrego Palm Canyon (sites 90-120)
#
#    FacilityId UnitName  UseType  UnitSpec  IsAda  IsTentSite  IsRvSite  \
# 0         777      103  Nightly  Campsite  False        True      True
# 1         777      103  Nightly  Campsite  False        True      True
# 2         777      103  Nightly  Campsite  False        True      True
# 3         777      103  Nightly  Campsite  False        True      True
# 4         777      103  Nightly  Campsite  False        True      True
#
#    VehicleLength UnitType   ArrivalDate
# 0             25  Camping  2/11/21 0:00
# ...

# %%
camping_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63179 entries, 0 to 63178
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ParkName       63179 non-null  object
#  1   ParkId         63179 non-null  int64
#  2   FacilityName   63179 non-null  object
#  3   FacilityId     63179 non-null  int64
#  4   UnitName       63179 non-null  object
#  5   UseType        63179 non-null  object
#  6   UnitSpec       63179 non-null  object
#  7   IsAda          63179 non-null  bool
#  8   IsTentSite     63179 non-null  bool
#  9   IsRvSite       63179 non-null  bool
#  10  VehicleLength  63179 non-null  int64
#  11  UnitType       63179 non-null  object
#  12  ArrivalDate    63179 non-null  object
# dtypes: bool(3), int64(3), object(7)
# memory usage: 5.0+ MB

# %%
camping_df[['FacilityName', 'UnitType']].head()
# Out:
#                          FacilityName UnitType
# 0  Borrego Palm Canyon (sites 90-120)  Camping
# 1  Borrego Palm Canyon (sites 90-120)  Camping
# 2  Borrego Palm Canyon (sites 90-120)  Camping
# 3  Borrego Palm Canyon (sites 90-120)  Camping
# 4  Borrego Palm Canyon (sites 90-120)  Camping
